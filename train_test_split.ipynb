# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
data_cleaned = pd.read_csv('prepared_data.csv')

# %%
data_cleaned
# Out:
#     № \nп/п  Институт  Учебная группа  Право  Физическая культура  \
# 0         9  0.163399        0.163399     -1                    1
# 1        43  0.081699        0.163399     -1                    1
# 2        44  0.054466        0.081699     -1                    1
# 3        59  0.040850        0.163399     -1                    1
# 4        78  0.032680        0.163399     -1                    1
# ..      ...       ...             ...    ...                  ...
# 148   1 620  0.166200        0.081699      1                    1
# 149   1 643  0.145425        0.163399      1                    1
# 150   1 651  0.129267        0.081699      1                    1
# 151   1 694  0.116340        0.163399      1                    0
# 152   1 696  0.196673        0.581699      0                    1
#
#      Инженерная и компьютерная графика  История  \
# 0                                   -1       -1
# 1                                   -1       -1
# 2                                   -1       -1
# 3                                   -1       -1
# 4                                   -1       -1
# ..                                 ...      ...
# 148                                 -1        1
# 149                                 -1        1
# 150                                 -1        1
# 151                                 -1        0
# 152                                 -1        0
#
#      Безопасность жизнедеятельности  Инженерная и компьютерная графика.1  \
# 0                                 2                                   -1
# 1                                 5                                   -1
# 2                                 5                                   -1
# 3                                 2                                   -1
# 4                                 2                                   -1
# ..                              ...                                  ...
# 148                              -1                                   -1
# 149                              -1                                   -1
# 150                              -1                                   -1
# 151                              -1                                   -1
# 152                              -1                                   -1
#
#      История.1  ...  Иностранный язык  Геодезия  \
# 0            3  ...                -1        -1
# 1            2  ...                -1        -1
# 2            3  ...                -1        -1
# 3            3  ...                -1        -1
# 4            3  ...                -1        -1
# ..         ...  ...               ...       ...
# 148         -1  ...                 2        -1
# 149         -1  ...                 2        -1
# 150         -1  ...                 3        -1
# 151         -1  ...                 2        -1
# 152         -1  ...                 3        -1
#
#      Инженерная компьютерная графика  Информатика  \
# 0                                 -1           -1
# 1                                 -1           -1
# 2                                 -1           -1
# 3                                 -1           -1
# 4                                 -1           -1
# ..                               ...          ...
# 148                               -1            3
# 149                               -1            3
# 150                               -1            2
# 151                               -1            2
# 152                               -1            3
#
#      Программирование и алгоритмизация  Практическая фонетика  Математика  \
# 0                                   -1                      3          -1
# 1                                   -1                      3          -1
# 2                                   -1                      3          -1
# 3                                   -1                      3          -1
# 4                                   -1                      3          -1
# ..                                 ...                    ...         ...
# 148                                 -1                     -1           3
# 149                                 -1                     -1           0
# 150                                 -1                     -1           2
# 151                                 -1                     -1           2
# 152                                 -1                     -1           3
#
#      Иностранный язык.1  Долги  отчислен
# 0                     5    1.0         0
# 1                     3    1.0         0
# 2                     0    1.0         0
# 3                     4    1.0         0
# 4                     4    1.0         0
# ..                  ...    ...       ...
# 148                  -1    1.0         0
# 149                  -1    2.0         0
# 150                  -1    2.0         0
# 151                  -1    5.0         1
# 152                  -1    2.0         0
#
# [153 rows x 21 columns]

# %%
target_column = 'отчислен'
X = data_cleaned.drop(target_column,axis =1)
y = data_cleaned[target_column]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.22, random_state=52)

# %%
print("Размер тренировочного набора:", X_train.shape)
print("Размер тестового набора:", X_test.shape)
# Out:
# Размер тренировочного набора: (119, 20)
# Размер тестового набора: (34, 20)

# %%
data_cleaned.to_csv('final_data.csv', index=False)
X_train.to_csv('X_train.csv', index=False)
X_test.to_csv('X_test.csv', index=False)
y_train.to_csv('y_train.csv', index=False)
y_test.to_csv('y_test.csv', index=False)
